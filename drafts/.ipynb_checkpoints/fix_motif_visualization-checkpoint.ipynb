# %%
#!/usr/bin/env python
from IPython.display import Image

from __future__ import print_function

import argparse
import h5py

from keras.models import model_from_json
import keras.backend as K

import os
import sys

sys.path.insert(0, os.path.abspath('..'))
os.chdir('../CoMET')

from evolutron.engine import DeepTrainer
from evolutron.tools import load_dataset, Handle, shape
from evolutron.motifs import motif_extraction

from sklearn.preprocessing import normalize

import numpy as np

import weblogolib as wl
from corebio.seq_io import SeqList
options = wl.LogoOptions()
options.color_scheme = wl.std_color_schemes["chemistry"]
# Out:
# Using Theano backend.
# Using gpu device 1: GeForce GTX 1080 (CNMeM is enabled with initial size: 80.0% of memory, cuDNN 5105)

# %%
filename = 'models/zinc/100_20_100_50_krswDeepCoDER.model'
hf = h5py.File(filename)
model_config = hf.attrs['model_config'].decode('utf8')
hf.close()

# %%
import evolutron.networks.krs.extra_layers as extra
custom_layers = {
    'Convolution1D': extra.Convolution1D,
    'Deconvolution1D': extra.Deconvolution1D,
    'MaxPooling1D': extra.MaxPooling1D,
    'Unpooling1D': extra.Unpooling1D,
    'Dense': extra.Dense,
    'Dedense': extra.Dedense,
    'Reshape': extra.Reshape,
    'Flatten': extra.Flatten
}

net = DeepTrainer(model_from_json(model_config, custom_objects=custom_layers))
net.load_all_param_values(filename)

handle = Handle.from_filename(filename)
data_id = handle.dataset

x_data = load_dataset(data_id, padded=True)
# Out:
# Dataset size: 11906

# %%
conv_layers = net.get_conv_layers()
conv_scores = conv_layers[0].output
custom_fun = K.function([net.inp], conv_scores)

# %%
res = custom_fun([[x_data[1]]]).squeeze()

# %%
filter_length=handle.filter_size
filters = handle.filters
depth = 0
vf = filter_length + depth * (filter_length - 1)

# %%
seq_scores = np.asarray([np.squeeze(custom_fun([[y]]), 0) for y in x_data])

# %%
seq_scores.shape
# Out:
# (11906, 3427, 100)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(seq_scores[:100,500,0])
# Out:
# <img src="data:image/png;base64,...">
